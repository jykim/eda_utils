# %%
import os
import sys
import time
import json
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
import scipy.stats as stats
from importlib import reload
from collections import OrderedDict
from functools import reduce

style.use('fivethirtyeight')
sns.set(color_codes=True)
# %config InlineBackend.figure_format = 'retina'
# %autosave 0
# Out:
# Autosave disabled

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %%
from google.cloud import bigquery as bq
import logging
from google.auth import _default

# %%
if any(['VELLUM' in k for k in os.environ.keys()]):
    pip_output = !pip install banjo
    DEBUG_OUTPUT = False
else:
    DEBUG_OUTPUT = True

import e3tools.eda_table as et
import e3tools.eda_display_utils as edu
import e3tools.eda_bq_utils as ebu

# %%
BQ_PROJECT_NAME = "lifidea7"

# %% [markdown]
# # Read Data

# %%
raw_sql = """
SELECT 
    * 
FROM `bigquery-public-data.ml_datasets.census_adult_income`
"""
raw = ebu.sample_bq_table(raw_sql, project_id=BQ_PROJECT_NAME, dialect='standard')
len(raw)
# Out:
# Downloading: 100%|██████████| 32561/32561 [00:04<00:00, 7891.63rows/s]
# 32561

# %%
eda = et.EDATable(raw)

# %%
eda.colinfo()
# Out:
# Total: 32561 rows
#                   DataType  ValueCount  NullCount  ZeroCount  \
# age                  int64          73          0          0
# workclass           object           9          0          0
# functional_weight    int64       21648          0          0
# education           object          16          0          0
# education_num        int64          16          0          0
# marital_status      object           7          0          0
# occupation          object          15          0          0
# relationship        object           6          0          0
# race                object           5          0          0
# sex                 object           2          0          0
# capital_gain         int64         119          0      29849
# capital_loss         int64          92          0      31042
# hours_per_week       int64          94          0          0
# native_country      object          42          0          0
# ...

# %% [markdown]
# # Overall Data Dist

# %%
eda.desc(outputcol=4)
# Out:
# <table style='border:0'><tr style='border:0'><td style='border:0'><img src="...%...%2Bvx5NPPonExETceeedeP7559HW1uauSyEDFBVo4pHUajVWrlyJuLg4fPnll/j000/h4%2BODl156CSaTCY8%2B%2Bih4PB4%2B/fRTPPvss3j77bdt9l%2B1ahVYlsWOHTvw3nvvoaKiAk899ZSbroYMWCwhHqihoYF9//33WaPRaN327bffsrGxsezRo0fZ%2BPh4trGx0freRx99xMbExLAsy7InTpxgExISWL1eb32/pqaGjYmJYYuKilx3EWTA83L3HwhC3CEwMBCLFi3Chx9%2BiMLCQpSXl6OgoAAWiwVFRUUIDw%2BHXC63xicmJlr/XVJSAq1Wi5SUlE7HLSsrQ0xMjEuugQx8VKCJR6qrq8PChQuhUCgwbdo0pKWlobGxEWvXroWXlxdYlr3lviaTCWFhYfjXv/7V6b3AwEBnpk08DPVBE4904MABCAQC5OTkICMjA1OmTEFNTQ0AICYmBtevX0dTU5M1/sKFC9Z/KxQK1NXVwcfHB5GRkYiMjIS3tzdee%2B01m30IsRcVaOKR/P390dDQgB9%2B%2BAFVVVX44osv8N577wFo785QKBT485//jOLiYhw9etTmJuEdd9yBESNG4KmnnsLFixdRWFiIZ555BpWVlQgPD3fXJZEBiGFv91mOkAHKYrHg1Vdfxddffw2j0YgRI0Zg%2BfLlePrpp/Hhhx8iODgYL7zwAs6ePYuwsDDMmzcPW7duxcWLFwEANTU12LhxI44fPw4ej4eUlBQ8//zzCAsLc/OVkYGECjQhHTQ2NiIvLw8zZ860bvvmm2/w17/%2BFQcPHnRjZsTTUBcHIR0wDIPVq1fjn//8J6qqqnDmzBls3rwZqamp7k6NeBhqQRPShUOHDuGtt95CWVkZ/Pz8cO%2B99%2BLJJ5%2B
# ...

# %% [markdown]
# # Data Dist by Label

# %%
eda.desc_group("income_bracket", figsize=(6,4))
# Out:
# <table style='border:0'><tr style='border:0'><td style='border:0'><b>income_bracket:  <=50K</b></td><td style='border:0'><b>income_bracket:  >50K</b></td></tr><tr style='border:0'><td style='border:0'><img src="...%2B/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjEsIGh0dHA6Ly9tYXRwbG90bGliLm9yZy8QZhcZAAAgAElEQVR4nO3deVzU1f4/8NcMM8Mw7DsiiwoiuAIiaG65piJmi7ZZ%2BYu6md%%2B%2B9SE5OBgAUFRUhPj4e4eHhmDp1Kr766isMGDDA8NzS0lI888wziIiIwJgxY/Dqq6%2BipqbGXG%2BFyGIwgRF1srq6OjzxxBMICwvDd999h6%2B//hr29vZ444030NjYiD/96U%2BQSqX4%2BuuvsWzZMvzjH/8wev6iRYsghMBXX32Fjz76CPn5%2BViyZImZ3g2RBRFE1KkuX74s/v3vfwudTmco27NnjwgNDRW//PKLGDRokCgrKzMc%2B%2BKLL0RISIgQQogjR46I8PBwodFoDMeLi4tFSEiISE9P77o3QWSBZOZOoETdnbu7O%2BbMmYPNmzcjLS0
# ...
